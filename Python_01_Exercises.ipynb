# %% [markdown]
# <b> Exercises for Python Module 1 </b>
#
# Make sure to comment all your code!

# %% [markdown]
# Accept the user's first and last name and print them in reverse order with a space between them.
#
# Keyword hints: print function, input function, append, add, string

# %%
firstname = input("Enter your first name ")
lastname = input("Enter your last name")
print (lastname +" "+ firstname)
# Out:
# Enter your first name dss
# Enter your last namehlkh
# hlkh dss

# %% [markdown]
# Ask the user "What country are you from?" then print the following statement: "I have heard that [input] is a beautiful country!"

# %%
country1 = input("What country are you from?")
print("I have heard that "+country1+ "is a beautiful country")
# Out:
# What country are you from?sdf
# I have heard that sdfis a beautiful country

# %% [markdown]
# Explain the output for:
#
# x = 36 / 4 * (3 +  2) * 4 + 2

# %%
x= 36 / 4 * (3 + 2) * 4 + 2
print(x)
# Out:
# 182.0

# %% [markdown]
# What is the output of the following code and what arithmetic operators is being used here?
#
# print(2%6)

# %%
print(2%6)
#modulus
# Out:
# 2

# %% [markdown]
# What is the output of the following code and what arithmetic operators are used here?
#
# print(2 * 3 ** 3 * 4)

# %%
print(2 * 3 ** 3 * 4)
# * is multiplication
# ** is exponential
# Out:
# 216

# %% [markdown]
# Accept an integer (n) and compute the value of n+nn+nnn. For example, if n = 4, then n+nn+nnn should equal 492.
#
# Keyword hints: Hint(4+44+444)

# %%
i = input("Enter input")
a = i+i
print(a)
b = i+i+i
print(b)
d = int(i)+int(a)+int(b)
print(d)
# Out:
# Enter input4
# 44
# 444
# 492

# %% [markdown]
# What is an IDE?

# %% [markdown]
# Integrated development environment

# %% [markdown]
# What is a Text Editor?

# %% [markdown]
# A text editor is a computer program that enables users to create, change, or edit plain text files

# %% [markdown]
# What is  filepath?

# %% [markdown]
# A file path specifies the location of a file in a computer's file system structure

# %% [markdown]
# Describe Python as a programming language?

# %% [markdown]
# Python is a general-purpose language, meaning it can be used to create a variety of different programs and isn't specialized for any specific problems

# %% [markdown]
# What is Jupyter Notebook, and how does it differ from other IDEs such as VSCode?

# %% [markdown]
# Jupyter Notebook and VSCode are both powerful tools for data science. Jupyter Notebook excels at interactive data analysis and collaboration, while VSCode excels at coding and debugging.

# %% [markdown]
# What is the difference between a "code" cell (at the top of your notebook) and a "markdown" cell?

# %% [markdown]
# Markdown is a lightweight and popular Markup language which is a writing standard for data scientists and analysts.
# Code cells are actual code that are executed

# %% [markdown]
# Describe each operator catagory: (Notebook 01_03)

# %% [markdown]
# arithmetic operators:  arithmetic operators are used to perform mathematical operations on numerical values
# assignment operators: assignment operators are used to assign values to variables.
# comparison operators: comparison operators compare the values on either sides of them and decide the relation among them
# identity operators :The identity operators, "is" and "is not" check for object identity.
# membership operators :Membership operators check for membership within compound objects
# boolean operators: When working with Boolean values these operators are used

# %% [markdown]
# Describe what the phrase "everything is an object" means in Python; what is an object?

# %% [markdown]
# Python is an object oriented programming language. Almost everything in Python is an object, with its properties and methods
